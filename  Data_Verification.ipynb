# %%
import os
from glob import glob
import shutil
from tqdm import tqdm

# %%
data_list=glob('../../data/raw/D*/')

# %%
for i in tqdm(range(len(data_list))):
    data_path=data_list[i]
    file_list=glob(data_path+'*.mp4')
    if len(file_list)!=3:
        print(data_path)
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 879.44it/s]

# %%
os.path.basename(data_path)
# Out:
# ''
